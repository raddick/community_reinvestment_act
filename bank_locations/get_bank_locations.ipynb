# %%
import urllib
from bs4 import BeautifulSoup as bs
import pandas
import numpy as np
import os
import datetime
import dateutil
from pprint import pprint
#print(token)
print("Done")
# Out:
# Done

# %%
url = 'https://www5.fdic.gov/idasp/ExternalConfirmation.asp?inCert1=4829'
#    print(i,":",url)
page = urllib.request.urlopen(url).read()
    # Parse HTML to find the contents of every <p>...</p> tag
soup = bs(page, "html.parser")
pprint(soup)
# Out:
# <script language="javascript1.1" type="text/javascript">
# // Script contents copyright Citrix Systems 2007, and implementation covered by international intellectual property laws.
# // change nothing below here
# var g_csma_Start = _csma_NSISOD(new Date());
# var _csma_NS_IID='00000000-0000-1000-9678-00e0ed25a6ac';
# var _vsvrname = _csma_trimmer('www5.fdic.gov_443(10.30.1.65:443).87:443)                                                                                                                                         ');
# var _vsvr_svc = _csma_trimmer('intwweb003cp.internet.fdic.gov_80(192.147.69.16:80)                                                                                                                               ');
# function _csma_trimmer(s)
# {
#   var cB = s.indexOf(")");
#   return s.substring(0,cB+1);
# }
# var g_csma_NS_PSD='&iid='+_csma_NS_IID+'&xid=006eae6b-8fe2-1b78-9678-00e0ed25a6ac&esnsid=00000000008597060640&reqrtb=00000000002411679829&reqstb=00000000002411679829&resrtb=00000000002411932546&resstb=00000000002411932546&vsvrname='+ _vsvrname + '&vsvr_svc=' + _vsvr_svc;var g_csma_PageEndData='';var g_csma_i=0;var g_csma_c=0;
# function _csma_NSGB(e){document.cookie='NSC_ESNS=reset; expires=Thu, 01 Jan 1970 00:00:01 GMT;';_csma_NSLR('test.aspx?s=x');}
# function _csma_NSI(e){_csma_NSLR('test.aspx?s=i');g_csma_i=1;}
# function _csma_NSDC(e){_csma_NSLR('test.aspx?s=c');g_csma_c=1;}
# function _csma_NSDL(e){if(document.readyState=="complete"){_csma_NSDC(e);}else if(document.readyState=="interactive"){_csma_NSI(e);}}
# function _csma_NSTC(o){var d=50,c=100,i=0;for(i=0;i<c;i++){if(!o.complete){setTimeout(function(){return;},d);}else {break;}}}
# function _csma_NSISOD(dt){return ''+dt.getUTCFullYear()+'-'+(dt.getUTCMonth()+1)+'-'+dt.getUTCDate()+'T'+dt.getUTCHours()+':'+dt.getUTCMinutes()+':'+dt.getUTCSeconds()+'.'+dt.getUTCMilliseconds()+'Z'+dt.getTimezoneOffset();}
# if(window.attachEvent&&document.attachEvent){document.attachEvent('onreadystatechange',_csma_NSDL);window.attachEvent('onbeforeunload',_csma_NSGB);} else if(window.addEventListener){window.addEventListener('DOMContentLoaded',_csma_NSI,false );window.addEventListener('load',_csma_NSDC,false);window.addEventListener('unload',_csma_NSGB,false);}
# function _csma_NSSS(o,t){ o.src='/ens10/app/ext/suser/'+t; }
# function _csma_NSLR(m){var s=new String(document.location);var o=document.createElement('img');if(o){var dt=new Date();var l=s.indexOf('?');var p=(l<0)?document.location:s.substr(0,l);_csma_NSSS(o,m+'&p='+escape(p)+'&dt='+_csma_NSISOD(dt)+'&st='+g_csma_Start+'&fi='+g_csma_i+'&fc='+g_csma_c+g_csma_NS_PSD+g_csma_PageEndData);_csma_NSTC(o);}}
# </script><!-- Security Remediation Project -->
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <title>FDIC: Institution Directory - External Confirmation</title>
# <meta charset="utf-8"/>
# <meta content="IE=9, edge" http-equiv="X-UA-Compatible"/>
# <style>
#        .pageContainer {width: 995px; }
#        .reportHeaderContainer { border:none; width: 100%; height:80px; display:none; overflow:hidden;}
#        .contentFrameContainer { width: 100%; height:100%; margin:0; border:none; min-height: 1000px;}
#     </style>
# <script src="js/jquery-1.11.3.js" type="text/javascript"></script>
# <script type="text/javascript">
#
#         $(document).ready(function () {
#
#         }); //end of $(document).ready()
#
#         // show the report header iFrame
#         function ShowHeaderFrame(isVisible) {
#             if (isVisible) {
#                 $("#reportHeader").show();
#             } else {
#                 $("#reportHeader").hide();
#             }
#         }
#
#         function autoResizeFrame() {
#             $('#content').height($('#content').contents().height());
#         }
#     </script>
# </head>
# <body>
# <div class="pageContainer">
# <!-- begin Bread Crumbs -->
# <p hidden="" id="hmenu"> Banks </p>
# <p hidden="" id="hcurritem"> Details and Financials - ID </p>
# <p hidden="" id="hhead"> Confirmation &amp; Report</p>
# <!-- end Bread Crumbs -->
# <!-- The FDIC Header -->
# <!-- Last Updated Date: 1-21-2011   Time: 9:20AM   Version: 1.6 -->
# <!-- ForeSee Code -->
# <script src="/foresee/foresee-trigger.js" type="text/javascript"></script>
# <link href="/header/css/www2_header_style.css" rel="stylesheet" type="text/css"/>
# <div id="header-container"> <!-- start of header container -->
# <!-- everything inside the header is held within this container -->
# <div id="header-nav">
# <div id="header-nav-left-container">
# <div id="header-nav-left">
# <a alt="FDIC Logo" href="http://www.fdic.gov/" target="_parent" title="FDIC Home - Federal Deposit Insurance Corporation">
# <div id="fdic-logo"></div>
# </a>
# </div> <!-- close header-nav-left -->
# <div id="header-nav-right">
# <div id="header-nav-right-top">
# <div id="fdic-title"></div>
# </div>
# <div id="header-nav-right-bottom">
# <h1>Each depositor insured to at least $250,000 per insured bank</h1>
# </div>
# </div> <!-- close header-nav-right -->
# </div> <!-- close header-nav-left-container -->
# <div id="header-nav-right-container">
# <div id="right-container-top">
# <div id="web2">
# <ul>
# <li><a href="http://www.fdic.gov/privacy.html?site=twitter" target="_parent"><img alt="Twitter" height="14px" src="/header/images/web2/twitter.png" title="Twitter"/></a></li>
# <li><img alt="" src="/header/images/Web2/web2_divider_line.png" style="margin-top:7px" title=""/></li></ul></div></div></div></div></div></div></body></html>
# <li><a href="http://www.fdic.gov/privacy.html?site=facebook" target="_parent"><img alt="Facebook" height="14px" src="/header/images/web2/facebook.png" title="Facebook"/></a></li>
# <li><img alt="" src="/header/images/Web2/web2_divider_line.png" style="margin-top:7px" title=""/></li>
# <li><a href="http://www.fdic.gov/privacy.html?site=youtube" target="_parent"><img alt="YouTube" height="14px" src="/header/images/web2/youtube.png" title="YouTube"/></a></li>
# <li><img alt="" src="/header/images/Web2/web2_divider_line.png" style="margin-top:7px" title=""/></li>
# <li><a href="http://www.fdic.gov/rss.html" target="_parent"><img alt="RSS" height="14px" src="/header/images/web2/rss.png" title="RSS"/></a></li>
# <li><img alt="" src="/header/images/Web2/web2_divider_line.png" style="margin-top:7px" title=""/></li>
# <li><a href="http://service.govdelivery.com/service/multi_subscribe.html?code=USFDIC" target="_parent"><img alt="Subscribe" height="14px" src="/header/images/web2/subscribe.png" title="Subscribe"/></a></li>
#
#
#  <!-- close right-container-right-top -->
# <div id="right-container-center">
# <div id="advanced-search" title="Advanced Search"><a href="http://www.fdic.gov/search/advanced.html" target="_parent">Advanced Search</a></div>
# </div> <!-- close right-container-right-center -->
# <div id="right-container-bottom">
# <div id="search">
# <form action="http://search.fdic.gov/search" id="searchform" method="get" name="gs" target="_parent">
# <fieldset>
# <div alt="Search Box" class="form" title="Search Box">
# <div class="search2">
# <label for="fdic_search"></label>
# <label for="searchsubmit"></label>
# </div>
# <input class="field" id="fdic_search" name="q" type="text" value=""/>
# <input alt="Search Icon" class="submit" id="searchsubmit" title="Search Icon" type="submit" value=""/>
# <input name="sort" type="hidden" value="date:D:L:d1"/>
# <input name="output" type="hidden" value="xml_no_dtd"/>
# <input name="ie" type="hidden" value="iso-8859-1"/>
# <input name="oe" type="hidden" value="iso-8859-1"/>
# <input name="client" type="hidden" value="wwwGOV"/>
# <input name="proxystylesheet" type="hidden" value="wwwGOV"/>
# <input name="site" type="hidden" value="default"/>
# </div>
# </fieldset>
# </form>
# </div> <!-- close id="search" -->
# </div> <!-- close right-container-right-bottom -->
#  <!-- close header-nav-right-container -->
#  <!-- close header-nav **This is the top part of the header** -->
#  <!-- end of the header-container -->
# <!-- The global nav menu -->
# <!--
#
# **********************************************************************************
#  Page Name:	   navBar.asp
#  Author:	   FDIC BDS Team
#  Description:  The global navigation menu
#  Revisions:
# **********************************************************************************
# -->
# <!-- The parameters defined in the following configuration file have different values
#      i.e. this file will be different in Dev, UAT, and production
# -->
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=9, edge" http-equiv="X-UA-Compatible"/>
# <title>Global Navigation</title>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="/NavMenu/css/bootstrap.min.css" rel="stylesheet"/>
# <link href="/NavMenu/css/jquery-ui.min.css" rel="stylesheet"/>
# <link href="/NavMenu/css/navBar.css" rel="stylesheet"/>
# <script src="/NavMenu/js/jquery-1.11.3.min.js"></script>
# <script src="/NavMenu/js/navBar.js"></script>
# <script src="/NavMenu/js/jquery-ui.min.js"></script>
# <script src="/NavMenu/js/bootstrap.min.js"></script>
# <script type="text/javascript">
#         var parentMenuIndex;
#         MyHome = 'https://www5.fdic.gov';
#         bankFindHome = 'https://research.fdic.gov/bankfind';
#         SEAFHome = 'https://efr.fdic.gov/fcxweb/efr/index.html';
#         $(document).ready(function () {
#             $('ul.dropdown-menu [data-toggle=dropdown]').on('click', function (event) {
#                 event.preventDefault();
#                 event.stopPropagation();
#                 $(this).parent().siblings().removeClass('open');
#                 $(this).parent().toggleClass('open');
#             });
#
#             //When a menu item <a href> is selected
#             $('.navbar-nav li a').click(function (event) {
#                 if (IsMobile()) return;
#
#                 var id = $(this).attr('id');
#                 var linkName = $(this).text();  //link name
#                 var url = $(this).attr('href') //get the target url
#
#                 if (id !== undefined && id != "") {
#                     CurrentMemuItem = linkName;
#                     // PrintMessage("id/linkName: " + id + "/" + linkName + "; url: " + url);
#
#                     var linkNameTmp = linkName.replace(/&/g, "").replace(/ /g, "");
#                     // PrintMessage("id/linkNameTmp: " + id + "/" + linkNameTmp + ", linkName:" + linkName);
#                     if (linkNameTmp.indexOf(id) >= 0) {//root level
#                         RootPath = id;
#                         if (RootPath.indexOf("FDIC") >= 0) {
#                             RootPath += " .gov";
#                         }
#                     } else {
#                         var idx = Math.floor(parseInt(id) / 100);
#                         RootPath = NavBarItemArray[idx];
#
#                         //PrintMessage('id  ' + id + '; idx  ' + idx);
#                         //PrintMessage("id: " + id + ", linkName:" + linkName + ", url= " + url + ", menu index= " + idx + ", RootPath= " + RootPath);
#                         // SetParentActive(RootPath); //Set the parent to active
#                     }
#
#                     //  UpdateBreadCrumb(""); //Update Bread Crumb
#                 }
#
#             }); //When a menu item <a href> is selected
#
#             //Mouse over the first level of menu items, hight light the first child
#             //.intro for the introductory text for the menu item
#             $('.intro').mouseover(function () {
#                 if (IsMobile()) return;
#                 var linkName = $(this).text();  //link name
#
#                 if (linkName !== undefined && linkName != "") {
#                     $(this).parent().siblings().removeClass('open'); //close the opened menu items
#                     $(this).parent().siblings().css({ "background-color": "#d5e6f6" });
#
#                     var showSlidePanel = false;
#                     linkName = linkName.substring(0, 20); //first 20 characters only
#                     if (linkName.indexOf("FDIC") >= 0) {
#                         MouseOverFdicFirstChild();
#                     } else {
#                         var firstChild;
#                         if (linkName.indexOf("Banks") >= 0) {
#                             firstChild = $('.navbar-nav li:nth-child(2) li a:first-child');
#                             showSlidePanel = true;
#                         } else if (linkName.indexOf("Reports & Analysis") >= 0) {
#                             firstChild = $('.navbar-nav li:nth-child(3) li a:first-child');
#                             showSlidePanel = true;
#                         } else if (linkName.indexOf("Reference Tables") >= 0) {
#                             firstChild = $('.navbar-nav li:nth-child(4) li a:first-child');
#                             showSlidePanel = true;
#                         } else if (linkName.indexOf("Data Download") >= 0) {
#                             firstChild = $('.navbar-nav li:nth-child(5) li a:first-child');
#                             showSlidePanel = true;
#                         }
#
#                         if (showSlidePanel) {
#                             firstChild.parent().siblings().children().css({ "background-color": "#374A60", "color": "#FFFFFF" }); //#147323 fix
#                             firstChild.first().css({ "color": "#020202", "background-color": "#d5e6f6" }); //added 12/13/15
#                             ShowSlidePanel(firstChild);
#                         }
#                     }
#                 }
#             });
#
#             $('.navbar-nav > li:last-child > a').focusout(function () {
#                 $(this).css({ "background-color": "#537291", "color": "#ffffff" });
#             });
#
#             //add border to top and bottom when tabbing over top level menu items
#             $('.navbar-nav > li > a').focusin(function () {
#                 $(this).css({ "border-top": "2px solid #0000FF", "border-bottom": "2px solid #0000FF" });
#                 $(this).parent().siblings().removeClass('open'); //close the opened menu items
#             });
#
#             $('.navbar-nav > li > a').focusout(function () {
#                 $(this).css({ "border-top": "none", "border-bottom": "none" });
#             });
#
#             $('.navbar-nav > li:last-child > a').focusin(function () {
#                 $(this).parent().siblings().removeClass('open');
#                 $(this).parent().toggleClass('open');
#                 $(this).css({ "background-color": "#d5e6f6", "color": "#020202" });
#             });
#
#             $('.navbar-nav > li:last-child > a').click(function (event) {
#                 var url = "https://research.fdic.gov/bankfind";
#                 if (url !== undefined && url != "") {
#                     location.href = url;
#                 }
#             });
#
#             //508
#             $("#BankFind").on("keyup", function (event) {
#                 if (event.keyCode == 13) {//enter key pressed
#                     var url = "https://research.fdic.gov/bankfind";
#                     if (url !== undefined && url != "") {
#                         location.href = url;
#                     }
#                 }
#             });
#
#             //Mouse over FDIC tab
#             $('.navbar-nav li:first-child a').mouseover(function () {
#                 $(this).parent().siblings().removeClass('open'); //close the opened menu items
#                 MouseOutFdicFirstChild(); //same effect as "mouse out" 1st child of FDIC tab
#             });
#
#             //Mouse over the 2nd level menu items, show the slide out panel.
#             $('.intro li a').mouseover(function () {
#                 //#147323 fix
#                 $(this).parent().siblings().children().css({ "background-color": "#374A60", "color": "#FFFFFF" });
#                 $(this).css({ "background-color": "#d5e6f6", "color": "#2c3b4d" });
#
#                 ShowSlidePanel($(this));
#             });
#
#             $('.intro li a').focusin(function () {
#                 ShowSlidePanel($(this));
#             });
#
#             //hide the slide-out panel
#             $('.navbar-nav li a').mouseout(function () {
#                 HideSlidePanel();
#             });
#
#             $('.navbar-nav li a').focusout(function () {
#                 HideSlidePanel();
#             });
#
#             //mouse over the 1st child of the dropdown menu of the 1st menu item (FDIC)
#             $('.navbar-nav li:first-child li:first-child a').mouseover(function () {
#                 MouseOverFdicFirstChild();
#             });
#
#             $('.navbar-nav li:first-child li:first-child a').focusin(function () {
#                 MouseOverFdicFirstChild();
#             });
#
#             //mouse out the 1st child of the dropdown menu of the 1st menu item (FDIC)
#             $('.navbar-nav li:first-child li:first-child a').mouseout(function () {
#                 MouseOutFdicFirstChild();
#             });
#
#             $('.navbar-nav li:first-child li:first-child a').focusout(function () {
#                 MouseOutFdicFirstChild();
#             });
#
#             //mouse over the 1st child of the dropdown menu of the 2nd to last menu items
#             $('.navbar-nav li:nth-child(n+2) li:first-child a').mouseover(function () {
#                 MouseOverNonFdicFirstChild();
#             });
#
#             $('.navbar-nav li:nth-child(n+2) li:first-child a').focusin(function () {
#                 MouseOverNonFdicFirstChild();
#             });
#
#             //mouse out the 1st child of the dropdown menu of the 2nd to last menu items
#             $('.navbar-nav li:nth-child(n+2) li:first-child a').mouseout(function () {
#                 MouseOutNonFdicFirstChild();
#             });
#             $('.navbar-nav li:nth-child(n+2) li:first-child a').focusout(function () {
#                 MouseOutNonFdicFirstChild();
#             });
#
#             //last child first level
#             $('.navbar-nav > li:last-child > a').focusin(function () {
#                 $("#dropdown-toggle").toggle();
#             });
#
#             //When the Bank Data Guide link is clicked
#             $("#bankDataGuideLink").on('click', function () {
#                 //window.location = bankDataGuideUrl;
#
#                 //Display target page in a iFrame
#                 $('#iframeID').attr({ src: bankDataGuideUrl });
#             });
#
#             //Help menu (6th column in the Nav bar)
#             $('.navbar-nav li:nth-child(6) li a').mouseover(function () {
#                 $('.navbar-nav li:nth-child(6) li a').css({ "background-color": "#374A60", "color": "#FFFFFF" });
#                 $(this).css({ "background-color": "#d5e6f6", "color": "#020202" });
#             });
#
#             $('.navbar-nav li:nth-child(6) li a').focusin(function () {
#                 $('.navbar-nav li:nth-child(6) li a').css({ "background-color": "#374A60", "color": "#FFFFFF" });
#                 $(this).css({ "background-color": "#d5e6f6", "color": "#020202" });
#             });
#
#             $('.navbar-nav > li:nth-child(6) > a').mouseover(function () {
#                 $('.navbar-nav li:nth-child(6) li:first-child a').css({ "background-color": "#374A60", "color": "#FFFFFF" });
#             });
#
#             //Initial
#             InitSetup();
#
#         }); //end of $(document).ready()
#
#     </script>
# </head>
# <body>
# <div class="navContainer" id="globalNavBar">
# <!-- Navigation -->
# <nav class="navbar navbar-default navbar-fixed-top nav_menu" role="navigation" style="clear:both; margin-top:20px;">
# <div class="navbar-header">
# <button class="navbar-toggle collapsed" data-target="#bs-FDIC-navbar-collapse-1" data-toggle="collapse" style="float:left;" type="button">
# <span class="sr-only">Toggle navigation</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# </div>
# <div class="collapse navbar-collapse" id="bs-FDIC-navbar-collapse-1">
# <ul class="nav navbar-nav" role="menubar">
# <li class="dropdown hidden-xs" role="presentation">
# <a aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" href="#" id="FDIC" role="menuitem" tabindex="3"> FDIC <span class="caret"></span></a>
# <ul aria-labelledby="FDIC" class="dropdown-menu global-menu hidden-xs" role="menu">
# <li role="presentation"><a href="https://www.fdic.gov" id="101" role="menuitem" tabindex="4"> Home </a></li>
# <li role="presentation"><a href="https://www.fdic.gov/deposit" id="102" role="menuitem" tabindex="5"> Deposit Insurance </a></li>
# <li role="presentation"><a href="https://www.fdic.gov/consumers" id="103" role="menuitem" tabindex="6"> Consumer Protection </a></li>
# <li role="presentation"><a href="https://www.fdic.gov/bank" id="104" role="menuitem" tabindex="7"> Industry Analysis </a></li>
# <li role="presentation"><a href="https://www.fdic.gov/regulations" id="105" role="menuitem" tabindex="8"> Regulations &amp; Examinations </a></li>
# <li role="presentation"><a href="https://www.fdic.gov/buying" id="106" role="menuitem" tabindex="9"> Institution &amp; Assets Sales </a></li>
# <li role="presentation"><a href="https://www.fdic.gov/news" id="107" role="menuitem" tabindex="10"> News &amp; Events </a></li>
# <li role="presentation"><a href="https://www.fdic.gov/about" id="108" role="menuitem" tabindex="11"> About FDIC </a></li>
# </ul>
# </li>
# <li class="dropdown" role="presentation">
# <a aria-haspopup="true" class="dropdown-toggle intro" data-toggle="dropdown" href="#" id="Banks" role="menuitem" tabindex="12"> Banks <span class="caret"></span>
# <span class="sr-only"><em>BankFind.</em> Learn if your bank is insured, View locations, Review a bank's  history, Get summary information.</span>
# </a>
# <ul aria-labelledby="Banks" class="dropdown-menu global-menu intro" role="menu">
# <li role="presentation">
# <a href="https://research.fdic.gov/bankfind" id="201" role="menuitem" tabindex="13"> BankFind
#                                   <span class="sr-only"><em>BankFind.</em> Learn if your bank is insured, View locations, Review a bank's  history, Get summary information.</span>
# </a>
# </li>
# <li role="presentation">
# <a href="/idasp/advSearchLanding.asp" id="202" role="menuitem" tabindex="14"> Details and Financials - ID
#                                 <span class="sr-only">
# <em>Institution Directory (ID).</em>Use more criteria to, Find FDIC Insured Banks and their locations, Get comprehensive financial or demographic reports,
#                                     Get current and historical data, Find groups of banks, Find a bank holding company (BHC).
#                                 </span>
# </a>
# </li>
# <li role="presentation">
# <a href="/sod/sodInstBranch.asp?barItem=1" id="203" role="menuitem" tabindex="15"> Branch Office Deposits
#                                     <span class="sr-only">
# <em>Summary of Deposits (SOD). </em>Results of the annual survey of branch office deposits as of June 30th  for all FDIC-insured institutions.
#                                     Data is available by institution and/or geographic area in reports or data downloads
#                                 </span>
# </a>
# </li>
# <li role="presentation">
# <a href="https://efr.fdic.gov/fcxweb/efr/index.html" id="204" role="menuitem" tabindex="16"> Securities Exchange Act Filings
#                                     <span class="sr-only">
# <em>Securities Exchange Act Filings. </em>This system contains two groups of securities disclosure filings:
#                                     Beneficial ownership report filings on Forms 3, 4, and 5 by directors, officers, and principal shareholders of depository institutions.
#                                     Other securities disclosure documents filed by or pertaining to FDIC-supervised depository institutions with a class of securities registered under the Exchange Act.
#                                     </span>
# </a>
# </li>
# </ul>
# </li>
# <li class="dropdown" role="presentation">
# <a aria-haspopup="true" class="dropdown-toggle intro" data-toggle="dropdown" href="#" id="ReportsAnalysis" role="menuitem" tabindex="17"> Reports &amp; Analysis <span class="caret"></span>
# <span class="sr-only">
# <em>Summary of Deposits (SOD). </em>Based on the annual survey of branch office deposits as of
#                             June 30th, market share reports are available by geographic area (Deposit Market Share Report, Pro Forma HHI) or by
#                             institution (Market Presence, Growth Rates).
#                             </span>
# </a>
# <ul aria-labelledby="ReportsAnalysis" class="dropdown-menu global-menu intro" role="menu">
# <li role="presentation">
# <a href="/sod/sodMarketBank.asp?barItem=2" id="301" role="menuitem" tabindex="18"> Deposit Market Share Reports
#                                     <span class="sr-only">
# <em>Summary of Deposits (SOD). </em>Based on the annual survey of branch office deposits as of
#                                         June 30th, market share reports are available by geographic area (Deposit Market Share Report, Pro Forma HHI) or by
#                                         institution (Market Presence, Growth Rates).
#                                     </span>
# </a>
# </li>
# <li role="presentation">
# <a href="/sdi/main.asp?formname=compare" id="302" role="menuitem" tabindex="19"> Comparison Reports - SDI
#                                     <span class="sr-only">
# <em>Statistics on Depository Institutions (SDI). </em>Financial data from  1992 to present,
#                                         Compare up to four columns. Create custom peers, reports, and downloads. Predefined industry reports.
#                                     </span>
# </a>
# </li>
# <li role="presentation">
# <a href="/sdi/main.asp?formname=standard" id="303" role="menuitem" tabindex="20"> Standard Industry Reports - SDI
#                                     <span class="sr-only">
# <em>Statistics on Depository Institutions (SDI). </em>Detailed aggregate financial information for common standard peer groups.
#                                         Based on legacy Statistics on Banking (SOB) reports.
#                                     </span>
# </a>
# </li>
# <li role="presentation">
# <a href="/hsob/SelectRpt.asp?EntryTyp=30&amp;Header=1&amp;tab=bankFailures" id="304" role="menuitem" tabindex="21"> Bank Failures
#                                     <span class="sr-only">
# <em>Historical Statistics on Banking (HSOB). </em>A complete look historically of bank failures and assistance
#                                         transactions of all FDIC-insured institutions back to 1934.
#                                     </span>
# </a>
# </li>
# <li role="presentation">
# <a href="/roc/index.asp" id="305" role="menuitem" tabindex="22"> Reports of Structure Changes
#                                     <span class="sr-only">
# <em>Reports of Structure Changes (ROC). </em>Searchable database for structure transactions (e.g., new institution, mergers, closings) for institutions
#                                         or offices for a specific date, date range, or quarter date based on either the processed date or effective date.
#                                     </span>
# </a>
# </li>
# </ul>
# </li>
# <li class="dropdown" role="presentation">
# <a aria-haspopup="true" class="dropdown-toggle intro" data-toggle="dropdown" href="#" id="ReferenceTables" role="menuitem" tabindex="23"> Reference Tables  <span class="caret"></span>
# <span class="sr-only">
# <em>Summary of Deposits (SOD). </em>Standardized tables provide aggregate results of the annual survey of branch office deposits (SOD) as of June 30th.
#                                 National, regional, state and county data are available for data back to 1994.
#                             </span>
# </a>
# <ul aria-labelledby="ReferenceTables" class="dropdown-menu global-menu intro" role="menu">
# <li role="presentation">
# <a href="/sod/sodSummary.asp?barItem=3" id="401" role="menuitem" tabindex="24"> Deposit Summary Tables
#                                     <span class="sr-only">
# <em>Summary of Deposits (SOD). </em>Standardized tables provide aggregate results of the annual survey of branch office deposits (SOD) as of June 30th.
#                                         National, regional, state and county data are available for data back to 1994.
#                                     </span>
# </a>
# </li>
# <li role="presentation">
# <a href="/hsob/SelectRpt.asp?EntryTyp=10&amp;Header=1&amp;tab=commBanks" id="402" role="menuitem" tabindex="25"> Annual Financial Data
#                                     <span class="sr-only">
# <em>Historical Statistics on Banking (HSOB). </em>Annual summary of financial and structural data back to 1934 for all FDIC-insured institutions.
#                                         These data can be used to identify and analyze long-term trends and to develop benchmarks to evaluate the current condition of the banking
#                                         and thrift industries. Commercial bank data back to 1934. Savings institution data back to 1984.
#                                     </span>
# </a>
# </li>
# </ul>
# </li>
# <li class="dropdown" role="presentation">
# <a aria-haspopup="true" class="dropdown-toggle intro" data-toggle="dropdown" href="#" id="DataDownload" role="menuitem" tabindex="26"> Data Download <span class="caret"></span>
# <span class="sr-only">
# <em>Statistics on Depository Institutions (SDI). </em>Quarterly financial data for all FDIC-Insured institutions. Predefined downloadable ZIP files contains all SDI Reports
#                                 and report items. Each ZIP file contains data for one reporting quarter.
#                             </span>
# </a>
# <ul aria-labelledby="DataDownload" class="dropdown-menu global-menu intro" role="menu">
# <li role="presentation">
# <a href="/sdi/download_large_list_outside.asp" id="501" role="menuitem" tabindex="27"> Quarterly Financial Data - SDI
#                                     <span class="sr-only">
# <em>Statistics on Depository Institutions (SDI). </em>Quarterly financial data for all FDIC-Insured institutions. Predefined downloadable ZIP files contains all SDI Reports
#                                         and report items. Each ZIP file contains data for one reporting quarter.
#                                     </span>
# </a>
# </li>
# <li role="presentation">
# <a href="/sdi/main.asp?formname=customddownload" id="502" role="menuitem" tabindex="28"> Custom Financial Data - SDI
#                                     <span class="sr-only">
# <em>Statistics on Depository Institutions (SDI). </em>Quarterly financial data for all FDIC-Insured institutions. Select report items from any SDI Report.
#                                         Select one or many FDIC Insured Institutions. Select time periods 1992 to present.
#                                     </span>
# </a>
# </li>
# <li role="presentation">
# <a href="/idasp/advSearch_warp_download_all.asp?intTab=1" id="503" role="menuitem" tabindex="29"> Institutions &amp; Locations - ID
#                                     <span class="sr-only">
# <em>Institution Directory (ID). </em>Predefined datasets for all FDIC-insured institutions (Updated weekly):
#                                         Current list of all institutions. Current locations for all institutions (branches and main offices).
#                                     </span>
# </a>
# </li>
# <li role="presentation">
# <a href="/idasp/advSearch_warp_download_all.asp?intTab=2" id="504" role="menuitem" tabindex="30"> Financial Data - SDI
#                                     <span class="sr-only">
# <em>Predefined datasets for all FDIC-insured institutions. </em>Each of the downloadable ZIP files contains all financial items available
#                                         for all FDIC insured institutions. Each ZIP file contains data for one reporting quarter.
#                                     </span>
# </a>
# </li>
# <li role="presentation">
# <a href="/idasp/advSearch_warp_download_all.asp?intTab=4" id="505" role="menuitem" tabindex="31"> Aggregate Time Series Data
#                                     <span class="sr-only">
# <em>Quarterly Banking Profile (QBP)Time Series Spreadsheets. </em>Aggregate data for all FDIC-insured institutions for each quarter
#                                         back to 1984 in downloadable Excel spreadsheet files.
#                                     </span>
# </a>
# </li>
# <li role="presentation">
# <a href="/sod/dynaDownload.asp?barItem=6" id="506" role="menuitem" tabindex="32"> Branch Office Deposits
#                                     <span class="sr-only">
# <em>Branch Office Deposits. </em>Annual Summary of Deposits survey of branch office deposits as of June 30. Data is available back to 1994.
#                                     </span>
# </a>
# </li>
# </ul>
# </li>
# <!--Beginning Help Menu -->
# <li class="dropdown" role="presentation">
# <a aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" href="#" id="GlobalHelp" role="menuitem" tabindex="33"> Help <span class="caret"></span></a>
# <!-- Parent Menu -->
# <ul aria-labelledby="GlobalHelp" class="dropdown-menu global-menu" id="helpOptions" role="menu">
# <li role="presentation">
# <a href="https://www.fdic.gov/bank/statistical/guide/" id="601" role="menuitem" tabindex="34" target="_blank"> Bank Data Guide</a>
# </li>
# <li role="presentation">
# <a class="js-addLegacyAppPrefix" href="/idasp/DIRSInfoRequest.asp" id="602" role="menuitem" tabindex="35" target="_blank">Questions</a>
# </li>
# <li role="presentation">
# <a class="js-addLegacyAppPrefix" href="/sdi/main.asp?formname=tutorial" id="603" role="menuitem" tabindex="36" target="_blank">Tutorials</a>
# </li>
# <li class="dropdown-submenu dropdown" role="presentation">
# <a aria-haspopup="true" class="dropdown-toggle hidden-xs" data-toggle="dropdown" href="#" id="BanksHelp" role="menuitem" tabindex="37"> Banks</a>
# <a aria-haspopup="true" class="dropdown-toggle visible-xs" data-toggle="dropdown" href="#"> Banks <span class="caret"></span></a>
# <ul aria-labelledby="BanksHelp" class="dropdown-menu help-menu" role="menu">
# <li class="dropdown-submenu dropdown" role="presentation">
# <a aria-haspopup="true" class="dropdown-toggle hidden-xs" data-toggle="dropdown" href="#" id="604" role="menuitem" tabindex="38">BankFind</a>
# <a aria-haspopup="true" class="dropdown-toggle visible-xs" data-toggle="dropdown" href="#"> BankFind <span class="caret"></span></a>
# <ul aria-labelledby="604" class="dropdown-menu help-menu" role="menu">
# <li role="presentation">
# <a class="homePage" href="https://research.fdic.gov/bankfind/glossary.html" role="menuitem" tabindex="39" target="_blank"> BankFind Glossary</a>
# </li>
# </ul>
# </li>
# <li class="dropdown-submenu dropdown" role="presentation">
# <a aria-haspopup="true" class="dropdown-toggle hidden-xs" data-toggle="dropdown" href="#" id="605" role="menuitem" tabindex="40">Details and Financials - ID</a>
# <a aria-haspopup="true" class="dropdown-toggle visible-xs" data-toggle="dropdown" href="#"> Details and Financials - ID <span class="caret"></span></a>
# <ul aria-labelledby="605" class="dropdown-menu help-menu" role="menu">
# <li role="presentation"><a href="/idasp/advInfoPage.asp?formname=sitemap" id="918" role="menuitem" tabindex="41" target="_blank" title="Glossary-ID">Glossary</a></li>
# <li role="presentation"><a href="/idasp/loadWhatsNew.asp" id="919" role="menuitem" tabindex="42" target="_blank" title="Data Availability-ID">  What's New and Data Availability</a></li>
# <li role="presentation"><a href="/idasp/advInfoPage.asp?formname=disclaimer" id="920" role="menuitem" tabindex="43" target="_blank" title="Disclaimer-ID"> Disclaimer and Methodology</a></li>
# </ul>
# </li>
# <li class="dropdown-submenu dropdown" role="presentation">
# <a aria-haspopup="true" class="dropdown-toggle hidden-xs" data-toggle="dropdown" href="#" id="610" tabindex="44"> Branch Office Deposits</a>
# <a aria-haspopup="true" class="dropdown-toggle visible-xs" data-toggle="dropdown" href="#">  Branch Office Deposits <span class="caret"></span></a>
# <ul aria-labelledby="610" class="dropdown-menu help-menu" role="menu">
# <li role="presentation"><a href="/sod/sodHelp.asp?barItem=8" id="611" role="menuitem" tabindex="45" target="_blank">  Help</a></li>
# <li role="presentation"><a href="/sod/sodDataAvailability.asp" id="612" role="menuitem" tabindex="46" target="_blank">  Data Availability</a></li>
# <li role="presentation"><a href="https://www.fdic.gov/regulations/resources/call/sod.html" id="613" role="menuitem" tabindex="47" target="_blank">  Financial Institution Letters</a></li>
# <li role="presentation"><a href="https://www.fdic.gov/regulations/resources/call/sod.html" id="614" role="menuitem" tabindex="48" target="_blank">   Reporting Instructions</a></li>
# <li role="presentation"><a href="/sod/sod_frm_inst.asp" id="615" role="menuitem" tabindex="49" target="_blank"> Survey Form Worksheet</a></li>
# <li role="presentation"><a href="https://www.fdic.gov/regulations/resources/call/sod.html" id="616" role="menuitem" tabindex="50" target="_blank">  Central Data Repository (CDR) </a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="dropdown-submenu dropdown" role="presentation">
# <a aria-haspopup="true" class="dropdown-toggle hidden-xs" data-toggle="dropdown" href="#" id="ReportsAnalysisHelp" role="menuitem" tabindex="51"> Reports &amp; Analysis </a>
# <a aria-haspopup="true" class="dropdown-toggle visible-xs" data-toggle="dropdown" href="#">  Reports &amp; Analysis <span class="caret"></span></a>
# <ul aria-labelledby="ReportsAnalysisHelp" class="dropdown-menu help-menu" role="menu">
# <li class="dropdown-submenu dropdown" role="presentation">
# <a aria-haspopup="true" class="dropdown-toggle hidden-xs" data-toggle="dropdown" href="#" id="617" tabindex="52">  Deposit Market Share Reports</a>
# <a aria-haspopup="true" class="dropdown-toggle visible-xs" data-toggle="dropdown" href="#">   Deposit Market Share Reports <span class="caret"></span></a>
# <ul aria-labelledby="617" class="dropdown-menu help-menu" role="menu">
# <li role="presentation"><a href="/sod/sodHelp.asp?barItem=8" id="618" role="menuitem" tabindex="53" target="_blank">  Help</a></li>
# <li role="presentation"><a href="/sod/sodDataAvailability.asp" id="619" role="menuitem" tabindex="54" target="_blank">  Data Availability</a></li>
# <li role="presentation"><a href="https://www.fdic.gov/regulations/resources/call/sod.html" id="620" role="menuitem" tabindex="55" target="_blank">  Financial Institution Letters</a></li>
# <li role="presentation"><a href="https://www.fdic.gov/regulations/resources/call/sod.html" id="621" role="menuitem" tabindex="56" target="_blank">   Reporting Instructions</a></li>
# <!--<li role="presentation"><a tabindex="57" role="menuitem" id="622" href="/sod/sod_frm_inst.asp" target="_blank"> Survey Form Worksheet</a></li>-->
# <li role="presentation"><a href="https://www.fdic.gov/regulations/resources/call/sod.html" id="623" role="menuitem" tabindex="58" target="_blank">  Central Data Repository (CDR)</a></li>
# </ul>
# </li>
# <li class="dropdown-submenu dropdown" role="presentation">
# <a aria-haspopup="true" class="dropdown-toggle hidden-xs" data-toggle="dropdown" href="#" id="624" tabindex="59"> Comparison Reports - SDI</a>
# <a aria-haspopup="true" class="dropdown-toggle visible-xs" data-toggle="dropdown" href="#">  Comparison Reports - SDI <span class="caret"></span></a>
# <ul aria-labelledby="624" class="dropdown-menu help-menu" role="menu">
# <li role="presentation"><a href="/sdi/main.asp?formname=glossary" id="625" role="menuitem" tabindex="60" target="_blank">  Glossary</a></li>
# <li role="presentation"><a href="/sdi/homehelp.asp?SystemForm=ID&amp;HelpItem=FAQ" id="626" role="menuitem" tabindex="61" target="_blank"> Frequently Asked Questions</a></li>
# <li role="presentation"><a href="/sdi/loadwhatsnew.asp" id="627" role="menuitem" tabindex="62" target="_blank">  What's New &amp; Data Availability</a></li>
# <li role="presentation">
# <a href="/sdi/main.asp?formname=disclaimer" id="628" role="menuitem" tabindex="63" target="_blank">Disclaimer &amp; Methodology</a>
# </li>
# </ul>
# </li>
# <li class="dropdown-submenu dropdown" role="presentation">
# <a aria-haspopup="true" class="dropdown-toggle hidden-xs" data-toggle="dropdown" href="#" id="630" tabindex="64"> Standard Industry Reports - SDI</a>
# <a aria-haspopup="true" class="dropdown-toggle visible-xs" data-toggle="dropdown" href="#">  Standard Industry Reports - SDI <span class="caret"></span></a>
# <ul aria-labelledby="630" class="dropdown-menu help-menu" role="menu">
# <li role="presentation"><a href="/sdi/main.asp?formname=glossary" id="631" role="menuitem" tabindex="65" target="_blank">  Glossary</a></li>
# <li role="presentation"><a href="/sdi/homehelp.asp?SystemForm=ID&amp;HelpItem=FAQ" id="632" role="menuitem" tabindex="66" target="_blank"> Frequently Asked Questions</a></li>
# <li role="presentation"><a href="/sdi/loadwhatsnew.asp" id="633" role="menuitem" tabindex="67" target="_blank">  What's New &amp; Data Availability</a></li>
# <li role="presentation">
# <a href="/sdi/main.asp?formname=disclaimer" id="634" role="menuitem" tabindex="68" target="_blank">Disclaimer &amp; Methodology</a>
# </li>
# </ul>
# </li>
# <li class="dropdown-submenu dropdown" role="presentation">
# <a aria-haspopup="true" class="dropdown-toggle hidden-xs" data-toggle="dropdown" href="#" id="636" role="menuitem" tabindex="69">  Bank Failures </a>
# <a aria-haspopup="true" class="dropdown-toggle visible-xs" data-toggle="dropdown" href="#">  Bank Failures <span class="caret"></span></a>
# <ul aria-labelledby="636" class="dropdown-menu help-menu" role="menu">
# <li role="presentation"><a href="/hsob/Help.asp?EntryTyp=60&amp;Header=1" id="637" role="menuitem" tabindex="70" target="_blank"> Help</a></li>
# <li role="presentation"><a href="/hsob/data_availability.asp" id="638" role="menuitem" tabindex="71" target="_blank">   Data Availability</a></li>
# <li role="presentation"><a href="/hsob/Helpindex.asp" id="639" role="menuitem" tabindex="72" target="_blank"> Index</a></li>
# </ul>
# </li>
# <li class="dropdown-submenu dropdown" role="presentation">
# <a aria-haspopup="true" class="dropdown-toggle hidden-xs" data-toggle="dropdown" href="#" id="640" role="menuitem" tabindex="73"> Reports of Structure Changes </a>
# <a aria-haspopup="true" class="dropdown-toggle visible-xs" data-toggle="dropdown" href="#"> Reports of Structure Changes  <span class="caret"></span></a>
# <ul aria-labelledby="640" class="dropdown-menu help-menu" role="menu">
# <li role="presentation"><a href="/roc/bimonth.aspx" id="641" role="menuitem" tabindex="74" target="_blank"> Glossary</a></li>
# <li role="presentation"><a href="/roc/data_availibility.aspx" id="642" role="menuitem" tabindex="75" target="_blank">  Data Availability</a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="dropdown-submenu dropdown" role="presentation">
# <a aria-haspopup="true" class="dropdown-toggle hidden-xs" data-toggle="dropdown" href="#" id="ReferenceTablesHelp" role="menuitem" tabindex="76"> Reference Tables</a>
# <a aria-haspopup="true" class="dropdown-toggle visible-xs" data-toggle="dropdown" href="#"> Reference Tables  <span class="caret"></span></a>
# <ul aria-labelledby="ReferenceTablesHelp" class="dropdown-menu help-menu" role="menu">
# <li class="dropdown-submenu dropdown" role="presentation">
# <a aria-haspopup="true" class="dropdown-toggle hidden-xs" data-toggle="dropdown" href="#" id="643" tabindex="77"> Deposit Summary Tables</a>
# <a aria-haspopup="true" class="dropdown-toggle visible-xs" data-toggle="dropdown" href="#"> Deposit Summary Tables <span class="caret"></span></a>
# <ul aria-labelledby="643" class="dropdown-menu help-menu" role="menu">
# <li role="presentation"><a class="js-addLegacyAppPrefix" href="/sod/sodHelp.asp?barItem=8" id="644" role="menuitem" tabindex="78" target="_blank">  Help</a></li>
# <li role="presentation"><a class="js-addLegacyAppPrefix" href="/sod/sodDataAvailability.asp" id="645" role="menuitem" tabindex="79" target="_blank">  Data Availability</a></li>
# <li role="presentation"><a href="https://www.fdic.gov/regulations/resources/call/sod.html" id="646" role="menuitem" tabindex="80" target="_blank">  Financial Institution Letters</a></li>
# <li role="presentation"><a class="js-addLegacyAppPrefix" href="https://www.fdic.gov/regulations/resources/call/sod.html" id="647" role="menuitem" tabindex="81" target="_blank">   Reporting Instructions</a></li>
# <!-- <li role="presentation"><a tabindex="82" class="js-addLegacyAppPrefix" role="menuitem" id="648" href="/sod/sod_frm_inst.asp" target="_blank"> Survey Form Worksheet</a></li> -->
# <li role="presentation"><a href="https://www.fdic.gov/regulations/resources/call/sod.html" id="649" role="menuitem" tabindex="83" target="_blank">  Central Data Repository (CDR) </a></li>
# </ul>
# </li>
# <li class="dropdown-submenu dropdown" role="presentation">
# <a aria-haspopup="true" class="dropdown-toggle hidden-xs" data-toggle="dropdown" href="#" id="650" role="menuitem" tabindex="84"> Annual Financial Data </a>
# <a aria-haspopup="true" class="dropdown-toggle visible-xs" data-toggle="dropdown" href="#"> Annual Financial Data <span class="caret"></span></a>
# <ul aria-labelledby="650" class="dropdown-menu help-menu" role="menu">
# <li role="presentation"><a class="js-addLegacyAppPrefix" href="/hsob/Help.asp?EntryTyp=60&amp;Header=1" id="651" role="menuitem" tabindex="85" target="_blank"> Help</a></li>
# <li role="presentation"><a class="js-addLegacyAppPrefix" href="/hsob/data_availability.asp" id="652" role="menuitem" tabindex="86" target="_blank">   Data Availability</a></li>
# <li role="presentation"><a class="js-addLegacyAppPrefix" href="/hsob/Helpindex.asp" id="653" role="menuitem" tabindex="87" target="_blank"> Index</a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="dropdown-submenu dropdown" role="presentation">
# <a aria-haspopup="true" class="dropdown-toggle hidden-xs" data-toggle="dropdown" href="#" id="DataDownloadHelp" role="menuitem" tabindex="88"> Data Download</a>
# <a aria-haspopup="true" class="dropdown-toggle visible-xs" data-toggle="dropdown" href="#"> Data Download <span class="caret"></span></a>
# <ul aria-labelledby="DataDownloadHelp" class="dropdown-menu help-menu" role="menu">
# <li class="dropdown-submenu dropdown" role="presentation">
# <a aria-haspopup="true" class="dropdown-toggle hidden-xs" data-toggle="dropdown" href="#" id="654" tabindex="89"> Quarterly Financial Data - SDI</a>
# <a aria-haspopup="true" class="dropdown-toggle visible-xs" data-toggle="dropdown" href="#"> Quarterly Financial Data - SDI <span class="caret"></span></a>
# <ul aria-labelledby="654" class="dropdown-menu help-menu" role="menu">
# <li role="presentation"><a class="js-addLegacyAppPrefix" href="/sdi/main.asp?formname=glossary" id="655" role="menuitem" tabindex="90" target="_blank">  Glossary</a></li>
# <li role="presentation"><a class="js-addLegacyAppPrefix" href="/sdi/homehelp.asp?SystemForm=ID&amp;HelpItem=FAQ" id="656" role="menuitem" tabindex="91" target="_blank"> Frequently Asked Questions</a></li>
# <li role="presentation"><a class="js-addLegacyAppPrefix" href="/sdi/loadwhatsnew.asp" id="657" role="menuitem" tabindex="92" target="_blank">  What's New &amp; Data Availability</a></li>
# <li role="presentation">
# <a class="js-addLegacyAppPrefix" href="/sdi/main.asp?formname=disclaimer" id="658" role="menuitem" tabindex="93" target="_blank">Disclaimer &amp; Methodology</a>
# </li>
# </ul>
# </li>
# <li class="dropdown-submenu dropdown" role="presentation">
# <a aria-haspopup="true" class="dropdown-toggle hidden-xs" data-toggle="dropdown" href="#" id="660" tabindex="94">  Custom Financial Data - SDI</a>
# <a aria-haspopup="true" class="dropdown-toggle visible-xs" data-toggle="dropdown" href="#">  Custom Financial Data - SDI <span class="caret"></span></a>
# <ul aria-labelledby="661" class="dropdown-menu help-menu" role="menu">
# <li role="presentation"><a class="js-addLegacyAppPrefix" href="/sdi/main.asp?formname=glossary" id="662" role="menuitem" tabindex="95" target="_blank">  Glossary</a></li>
# <li role="presentation"><a class="js-addLegacyAppPrefix" href="/sdi/homehelp.asp?SystemForm=ID&amp;HelpItem=FAQ" id="663" role="menuitem" tabindex="96" target="_blank"> Frequently Asked Questions</a></li>
# <li role="presentation"><a class="js-addLegacyAppPrefix" href="/sdi/loadwhatsnew.asp" id="664" role="menuitem" tabindex="97" target="_blank">  What's New &amp; Data Availability</a></li>
# <li role="presentation">
# <a class="js-addLegacyAppPrefix" href="/sdi/main.asp?formname=disclaimer" id="665" role="menuitem" tabindex="98" target="_blank">Disclaimer &amp; Methodology</a>
# </li>
# </ul>
# </li>
# <li class="dropdown-submenu dropdown" role="presentation">
# <a aria-haspopup="true" class="dropdown-toggle hidden-xs" data-toggle="dropdown" href="#" id="667" role="menuitem" tabindex="99"> Institutions &amp; Locations - ID</a>
# <a aria-haspopup="true" class="dropdown-toggle visible-xs" data-toggle="dropdown" href="#"> Institutions &amp; Locations - ID <span class="caret"></span></a>
# <ul aria-labelledby="667" class="dropdown-menu help-menu" role="menu">
# <li role="presentation"><a class="js-addLegacyAppPrefix" href="/idasp/advInfoPage.asp?formname=sitemap" id="668" role="menuitem" tabindex="100" target="_blank" title="Glossary-ID">Glossary</a></li>
# <li role="presentation"><a class="js-addLegacyAppPrefix" href="/idasp/loadWhatsNew.asp" id="669" role="menuitem" tabindex="101" target="_blank" title="Data Availability-ID">  What's New and Data Availability</a></li>
# <li role="presentation"><a class="js-addLegacyAppPrefix" href="/idasp/advInfoPage.asp?formname=disclaimer" id="670" role="menuitem" tabindex="102" target="_blank" title="Disclaimer-ID"> Disclaimer and Methodology</a></li>
# </ul>
# </li>
# <li class="dropdown-submenu dropdown" role="presentation">
# <a aria-haspopup="true" class="dropdown-toggle hidden-xs" data-toggle="dropdown" href="#" id="672" tabindex="103">  Financial Data - SDI</a>
# <a aria-haspopup="true" class="dropdown-toggle visible-xs" data-toggle="dropdown" href="#"> Financial Data - SDI <span class="caret"></span></a>
# <ul aria-labelledby="672" class="dropdown-menu help-menu" role="menu">
# <li role="presentation"><a class="js-addLegacyAppPrefix" href="/sdi/main.asp?formname=glossary" id="673" role="menuitem" tabindex="104" target="_blank">  Glossary</a></li>
# <li role="presentation"><a class="js-addLegacyAppPrefix" href="/sdi/homehelp.asp?SystemForm=ID&amp;HelpItem=FAQ" id="674" role="menuitem" tabindex="105" target="_blank"> Frequently Asked Questions</a></li>
# <li role="presentation"><a class="js-addLegacyAppPrefix" href="/sdi/loadwhatsnew.asp" id="675" role="menuitem" tabindex="106" target="_blank">  What's New &amp; Data Availability</a></li>
# <li role="presentation">
# <a class="js-addLegacyAppPrefix" href="/sdi/main.asp?formname=disclaimer" id="676" role="menuitem" tabindex="107" target="_blank">Disclaimer &amp; Methodology</a>
# </li>
# </ul>
# </li>
# <li class="dropdown-submenu dropdown" role="presentation">
# <a aria-haspopup="true" class="dropdown-toggle hidden-xs" data-toggle="dropdown" href="#" id="678" tabindex="108"> Branch Office Deposits</a>
# <a aria-haspopup="true" class="dropdown-toggle visible-xs" data-toggle="dropdown" href="#"> Branch Office Deposits <span class="caret"></span></a>
# <ul aria-labelledby="678" class="dropdown-menu help-menu" role="menu">
# <li role="presentation"><a class="js-addLegacyAppPrefix" href="/sod/sodDownloadHelp.asp" id="679" role="menuitem" tabindex="109" target="_blank">  Help</a></li>
# <li role="presentation"><a class="js-addLegacyAppPrefix" href="/sod/sodDataAvailability.asp" id="680" role="menuitem" tabindex="110" target="_blank">  Data Availability</a></li>
# <li role="presentation"><a href="https://www.fdic.gov/regulations/resources/call/sod.html" id="681" role="menuitem" tabindex="111" target="_blank">  Financial Institution Letters</a></li>
# <li role="presentation"><a class="js-addLegacyAppPrefix" href="https://www.fdic.gov/regulations/resources/call/sod.html" id="682" role="menuitem" tabindex="112" target="_blank">   Reporting Instructions</a></li>
# <!--<li role="presentation"><a tabindex="113" class="js-addLegacyAppPrefix" role="menuitem" id="683" href="/sod/sod_frm_inst.asp" target="_blank"> Survey Form Worksheet</a></li>-->
# <li role="presentation"><a href="https://www.fdic.gov/regulations/resources/call/sod.html" id="684" role="menuitem" tabindex="114" target="_blank">  Central Data Repository (CDR) </a></li>
# </ul>
# </li>
# </ul>
# </li>
# <!--Ending Help Menu -->
# </ul>
# </li>
# <li class="clearfix divider-vertical hidden-xs pull-right" role="presentation">
# <a id="BankFind" role="menuitem" tabindex="115"> BankFind </a>
# </li>
# </ul>
# </div>
# </nav> <!-- end Navigation -->
# <!-- start Bread Crumbs -->
# <div class="cssBreadCrumbContainer hidden-xs hidden-print" id="breadCrumb">
# <span class="cssBreadCrumb" id="breadCrumbPath"> </span>
# </div>
# <!-- end Bread Crumbs -->
# </div> <!-- DivNavBarContainer -->
# <div aria-hidden="true" class="cssSlidePanel hidden-xs" id="SlidePanel">
# <div class="cssMenuTitle" id="MenuTitle"> </div>
# <div class="cssMenuDesc" id="MenuDesc"> </div>
# </div>
# <!-- for testing, to be removed -->
# <!--
#
#         <div id="log" class="hidden-xs" style="position:absolute; top:20px;"></div>
#     -->
# </body>
# </html>
# <!-- Replace  <frame> with <iframe>, since <Frame> is not supported in HTML 5 -->
# <iframe class="reportHeaderContainer" id="reportHeader" name="reportHeader"></iframe>
# <!--- Working with a CERT/Institution --->
# <!--
#                         <frame name="header"  id="Global Navigation Bar" scrolling="no" noresize marginwidth="0" marginheight="5"  target="content" src="Header.asp">
# 					    <frame name="content" id="Main content frame for various ID search forms, lists, and reports" marginwidth="0" marginheight="0" src="Confirmation.asp?inCert1=4829">
#                       -->
# <iframe class="contentFrameContainer" id="content" name="content" onload="autoResizeFrame();" src="advSearchConfirmation.asp?inCert1=4829"> </iframe>
# <!--referpage=-->
# <table style="width:990px;border:0px;">
# <tr>
# <td style="padding-top:20px;text-align:right;width:80%;">
#
# 		     <!--- LastUpdated: externalconfirmation.asp: 5/15/2018 --->
# </td>
# <td> </td>
# </tr>
# </table>
# <!-- Begin Footer-->
# <div id="divFDICFooter">
# <!-- Last Updated Date: 5-20-2011   Time: 12:04AM   Version: 1.4 -->
# <link href="/header/css/www2_header_style.css" rel="stylesheet" type="text/css">
# <br/>
# <!-- begin footer -->
# <div id="footer-container">
# <div>
# <ul id="footer-top">
# <li><a href="http://www.fdic.gov/" target="_parent" title="Home">Home</a></li>
# <li>|</li>
# <li><a href="http://www.fdic.gov/about/contact/ask/" target="_parent" title="Contact Us">Contact Us</a></li>
# <li>|</li>
# <li><a href="http://www.fdic.gov/search/" target="_parent" title="Search">Search</a></li>
# <li>|</li>
# <li><a href="http://www.fdic.gov/help/" target="_parent" title="Help">Help</a></li>
# <li>|</li>
# <li><a href="http://www.fdic.gov/sitemap/" target="_parent" title="SiteMap">SiteMap</a></li>
# <li>|</li>
# <li><a href="http://www.fdic.gov/regulations/laws/forms/" target="_parent" title="Forms">Forms</a></li>
# <li>|</li>
# <li><a href="http://www.fdic.gov/quicklinks/spanish.html" target="_parent" title="En Español">En Español</a></li>
# </ul>
# </div>
# <div>
# <ul id="footer-middle">
# <li><a href="http://www.fdic.gov/about/policies/" target="_parent" title="Website Policies">Website Policies</a></li>
# <li>|</li>
# <li><a href="http://www.fdic.gov/about/privacy/policy/index.html" title="Privacy Policy">Privacy Policy</a></li>
# <li>|</li>
# <li><a href="http://www.fdic.gov/plainlanguage/index.html" target="_parent" title="USA.gov">Plain Writing Act of 2010 </a></li>
# <li>|</li>
# <li><a href="http://www.usa.gov/" target="_parent" title="USA.gov">USA.gov</a></li>
# <li>|</li>
# <li><a href="http://www.fdicoig.gov/" target="_parent" title="FDIC Office of Inspector General">FDIC Office of Inspector General</a></li>
# </ul>
# </div>
# <div>
# <ul id="footer-bottom">
# <li><a href="http://www.fdic.gov/about/freedom/" target="_parent" title="Freedom of Information Act (FOIA) Service Center">Freedom of Information Act (FOIA) Service Center</a></li>
# <li>|</li>
# <li><a href="http://www.fdic.gov/open/" target="_parent" title="FDIC Open Government Webpage">FDIC Open Government Webpage</a></li>
# <li>|</li>
# <li><a href="http://www.fdic.gov/about/diversity/nofear/" target="_parent" title="No FEAR Act Data">No FEAR Act Data</a></li>
# </ul>
# </div>
# </div><!-- end of footer container -->
# <!-- end footer -->
# <!--//Start Omniture Embed Code - This reference must be repeated due to use of frames in app design-->
# <script language="JavaScript" src="/s_code_v1.js" type="text/javascript"></script>
# <script language="JavaScript" type="text/javascript">
# /************* DO NOT ALTER ANYTHING BELOW THIS LINE ! **************/
# var s_code=s.t();if(s_code)document.write(s_code)</script>
# <script language="JavaScript" type="text/javascript">
# if(navigator.appVersion.indexOf('MSIE')>=0)document.write(unescape('%3C')+'\!-'+'-')
# </script>
# <noscript>
# <a href="http://www.omniture.com" title="Web Analytics">
# <img alt="" border="0" height="1" src="http://fdic.122.2o7.net/b/ss/fdicgovprod/1/H.21--NS/0?[AQB]%26cl=Session%26AQE" width="1"/></a>
# </noscript>
# <!--//End Omniture Embed Code-->
# </link></div>
# <script language="javascript" type="text/javascript">
#     function setFooterPosition() {
#         var element = document.getElementById("divFDICFooter");
#         if (element !== undefined && element !== null) {
#             var height = window.innerHeight || document.documentElement.clientHeight || document.body.clientHeight;
#             if (element.offsetTop + 88 < height) {
#                 element.style.position = "absolute";
#                 element.style.top = (height - 88) + "px";
#                 element.style.left = "0px";
#             }
#         }
#     }
#     setFooterPosition();
# </script>
# <!--End Footer-->
#
#
#
# <script language="javascript1.1" type="text/javascript">
# g_csma_PageEndData='&reqrte=00000000002411679829&reqste=00000000002411679829&resrte=00000000002411953873&resste=00000000002411953873&crtt=00000000000000000009&ct=text/html; charset=utf-8                                                                                                                                                          ';
# </script>
